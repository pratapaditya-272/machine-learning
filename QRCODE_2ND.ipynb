# %% [markdown]
# <a href="https://colab.research.google.com/github/pratapaditya-272/machine-learning/blob/main/QRCODE_2ND.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install qrcode[pil]

# %%
import qrcode as qr

# %%
from PIL import Image

# %%
  qr=qrcode.QRCode(version=1,
                   error_correction=qrcode.constants.ERROR_CORRECT_H,
                   box_size=10,border=4,)

# %%
qr.add_data("@adityapratapsingh6293")

# %%
qr.make(fit=True)

# %%
img=qr.make_image(fill_color="blue",back_color="white")

# %%
img.save("aditya_youtub.png")
